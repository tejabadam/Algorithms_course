# %%
# Make sure pandas is loaded
import pandas as pd

# read in the survey csv
surveys_df = pd.read_csv("surveys.csv")

# %%
# Method 1: select a 'subset' of the data using the column name
surveys_df['species_id']
# Out:
# 0         NL
# 1         NL
# 2         DM
# 3         DM
# 4         DM
# 5         PF
# 6         PE
# 7         DM
# 8         DM
# 9         PF
# 10        DS
# 11        DM
# 12        DM
# 13        DM
# 14        DM
# 15        DM
# 16        DS
# 17        PP
# 18        PF
# 19        DS
# 20        DM
# 21        NL
# 22        DM
# 23        SH
# 24        DM
# 25        DM
# 26        DM
# 27        DM
# 28        PP
# 29        DS
#         ...
# 35519     SF
# 35520     DM
# 35521     DM
# 35522     DM
# 35523     PB
# 35524     OL
# 35525     OT
# 35526     DO
# 35527     US
# 35528     PB
# 35529     OT
# 35530     PB
# 35531     DM
# 35532     DM
# 35533     DM
# 35534     DM
# 35535     DM
# 35536     DM
# 35537     PB
# 35538     SF
# 35539     PB
# 35540     PB
# 35541     PB
# 35542     PB
# 35543     US
# 35544     AH
# 35545     AH
# 35546     RM
# 35547     DO
# 35548    NaN
# Name: species_id, Length: 35549, dtype: object

# %%
# Method 2: use the column name as an 'attribute'; gives the same output
surveys_df.species_id
# Out:
# 0         NL
# 1         NL
# 2         DM
# 3         DM
# 4         DM
# 5         PF
# 6         PE
# 7         DM
# 8         DM
# 9         PF
# 10        DS
# 11        DM
# 12        DM
# 13        DM
# 14        DM
# 15        DM
# 16        DS
# 17        PP
# 18        PF
# 19        DS
# 20        DM
# 21        NL
# 22        DM
# 23        SH
# 24        DM
# 25        DM
# 26        DM
# 27        DM
# 28        PP
# 29        DS
#         ...
# 35519     SF
# 35520     DM
# 35521     DM
# 35522     DM
# 35523     PB
# 35524     OL
# 35525     OT
# 35526     DO
# 35527     US
# 35528     PB
# 35529     OT
# 35530     PB
# 35531     DM
# 35532     DM
# 35533     DM
# 35534     DM
# 35535     DM
# 35536     DM
# 35537     PB
# 35538     SF
# 35539     PB
# 35540     PB
# 35541     PB
# 35542     PB
# 35543     US
# 35544     AH
# 35545     AH
# 35546     RM
# 35547     DO
# 35548    NaN
# Name: species_id, Length: 35549, dtype: object

# %%
# creates an object, surveys_species, that only contains the `species_id` column
surveys_species = surveys_df['species_id']

# %%
# select the species and plot columns from the DataFrame
surveys_df[['species_id', 'plot_id']]
# Out:
#       species_id  plot_id
# 0             NL        2
# 1             NL        3
# 2             DM        2
# 3             DM        7
# 4             DM        3
# 5             PF        1
# 6             PE        2
# 7             DM        1
# 8             DM        1
# 9             PF        6
# 10            DS        5
# 11            DM        7
# 12            DM        3
# 13            DM        8
# 14            DM        6
# 15            DM        4
# 16            DS        3
# 17            PP        2
# 18            PF        4
# 19            DS       11
# 20            DM       14
# 21            NL       15
# 22            DM       13
# 23            SH       13
# 24            DM        9
# 25            DM       15
# 26            DM       15
# 27            DM       11
# 28            PP       11
# 29            DS       10
# ...          ...      ...
# 35519         SF        9
# 35520         DM        9
# 35521         DM        9
# ...

# %%
# what happens when you flip the order?
surveys_df[['plot_id', 'species_id']]
# Out:
#        plot_id species_id
# 0            2         NL
# 1            3         NL
# 2            2         DM
# 3            7         DM
# 4            3         DM
# 5            1         PF
# 6            2         PE
# 7            1         DM
# 8            1         DM
# 9            6         PF
# 10           5         DS
# 11           7         DM
# 12           3         DM
# 13           8         DM
# 14           6         DM
# 15           4         DM
# 16           3         DS
# 17           2         PP
# 18           4         PF
# 19          11         DS
# 20          14         DM
# 21          15         NL
# 22          13         DM
# 23          13         SH
# 24           9         DM
# 25          15         DM
# 26          15         DM
# 27          11         DM
# 28          11         PP
# 29          10         DS
# ...        ...        ...
# 35519        9         SF
# 35520        9         DM
# 35521        9         DM
# ...

# %%
#what happens if you ask for a column that doesn't exist?
surveys_df['speciess']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/badt/anaconda/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5280)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5126)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20523)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20477)()
#
# KeyError: 'speciess'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
# Create a list of numbers:
a = [1, 2, 3, 4, 5]

# %%
a[0] ##gives the 1st element of the array
# Out:
# 1

# %%
a[5] ##index out of range error
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-b6a934feab86> in <module>()
# ----> 1 a[5]
#
# IndexError: list index out of range

# %%
a[len(a)]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-b61cb04f1416> in <module>()
# ----> 1 a[len(a)]
#
# IndexError: list index out of range

# %%
# select rows 0, 1, 2 (row 3 is not selected)
surveys_df[0:3]
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN

# %%
# select the first 5 rows (rows 0, 1, 2, 3, 4)
surveys_df[:5]
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
surveys_df[-1:]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 35548     NaN

# %%
# using the 'copy() method'
true_copy_surveys_df = surveys_df.copy()

# %%
# using '=' operator
ref_surveys_df = surveys_df

# %%
# iloc[row slicing, column slicing]
surveys_df.iloc[0:3, 1:4]
# Out:
#    month  day  year
# 0      7   16  1977
# 1      7   16  1977
# 2      7   16  1977

# %%
# select all columns for rows of index values 0 and 10
surveys_df.loc[[0, 10], :]
# Out:
#     record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0           1      7   16  1977        2         NL   M             32.0
# 10         11      7   16  1977        5         DS   F             53.0
#
#     weight
# 0      NaN
# 10     NaN

# %%
# what does this do?
surveys_df.loc[0, ['species_id', 'plot_id', 'weight']]
# Out:
# species_id     NL
# plot_id         2
# weight        NaN
# Name: 0, dtype: object

# %%
# What happens when you type the code below?
surveys_df.loc[[0, 10, 35549], :]
# Out:
#        record_id  month   day    year  plot_id species_id  sex  \
# 0            1.0    7.0  16.0  1977.0      2.0         NL    M
# 10          11.0    7.0  16.0  1977.0      5.0         DS    F
# 35549        NaN    NaN   NaN     NaN      NaN        NaN  NaN
#
#        hindfoot_length  weight
# 0                 32.0     NaN
# 10                53.0     NaN
# 35549              NaN     NaN

# %%
surveys_df.iloc[2, 6]
# Out:
# 'F'

# %%
surveys_df[0:1] ##prints the first row completely
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
#
#    weight
# 0     NaN

# %%
surveys_df[:4] ##prints first 4 rows completely
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN

# %%
surveys_df[:-1] #prints both head and tail
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# ...

# %%
surveys_df.iloc[0:4, 1:4]
# Out:
#    month  day  year
# 0      7   16  1977
# 1      7   16  1977
# 2      7   16  1977
# 3      7   16  1977

# %%
surveys_df.loc[[0:4], [1:4]]
# Out:
#   File "<ipython-input-32-018a2b0a449c>", line 1
#     surveys_df.loc[[0:4], [1:4]]
#                      ^
# SyntaxError: invalid syntax

# %%
surveys_df[surveys_df.year == 2002]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 33320      33321      1   12  2002        1         DM    M             38.0
# 33321      33322      1   12  2002        1         DO    M             37.0
# 33322      33323      1   12  2002        1         PB    M             28.0
# 33323      33324      1   12  2002        1         AB  NaN              NaN
# 33324      33325      1   12  2002        1         DO    M             35.0
# 33325      33326      1   12  2002        2         OT    F             20.0
# 33326      33327      1   12  2002        2         OT    M             20.0
# 33327      33328      1   12  2002        2         OT    F             21.0
# 33328      33329      1   12  2002        2         DM    M             37.0
# 33329      33330      1   12  2002        2         DO    M             35.0
# 33330      33331      1   12  2002        2         PE    F             21.0
# ...

# %%
surveys_df[surveys_df.year != 2002]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# ...

# %%
surveys_df[(surveys_df.year >= 1980) & (surveys_df.year <= 1985)]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 2270        2271      1   15  1980        8         DO    M             35.0
# 2271        2272      1   15  1980       11         PF    F             16.0
# 2272        2273      1   15  1980       18         DM    F             34.0
# 2273        2274      1   15  1980       11         DM    M             38.0
# 2274        2275      1   15  1980        8         DO    F             33.0
# 2275        2276      1   15  1980       11         DS    M             47.0
# 2276        2277      1   15  1980        8         PF    M             15.0
# 2277        2278      1   15  1980        9         OT    M             21.0
# 2278        2279      1   15  1980       11         DM    F             36.0
# 2279        2280      1   15  1980       21         OT    F             20.0
# 2280        2281      1   15  1980       11         OL    M             20.0
# ...

# %%
surveys_df[(surveys_df.year >= 1999) & (surveys_df.weight<= 8)]
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 29082      29083      1   16  1999       21         RM   M             16.0
# 29196      29197      2   20  1999       18         RM   M             18.0
# 29421      29422      3   15  1999       16         RM   M             15.0
# 29903      29904     10   10  1999        4         PP   M             20.0
# 29905      29906     10   10  1999        4         PP   M             21.0
# 30867      30868      6    4  2000        8         PP   F             21.0
# 30901      30902      7    1  2000        1         PP   M             20.0
# 31456      31457      9   31  2000        6         RM   M              8.0
# 31611      31612     11   26  2000       16         RM   M             17.0
# 31802      31803      3    3  2001       17         RM   M             16.0
# 31890      31891      3   25  2001        4         PF   M             17.0
# ...

# %%
surveys_df[surveys_df['species_id'].isin([1,4])]
# Out:
# Empty DataFrame
# Columns: [record_id, month, day, year, plot_id, species_id, sex, hindfoot_length, weight]
# Index: []
